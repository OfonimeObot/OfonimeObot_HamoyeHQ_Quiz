# %%
import numpy as np
import pandas as pd

food_data_df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')
food_data_df.to_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', index=False)

# %%
food_data_df.groupby('Area').sum()
# Out:
#                              Area Code  Item Code  Element Code       Y2014  \
# Area
# Algeria                           5252    3532053       5017927   313375.33
# Angola                            9968    3819908       5515088   208584.42
# Benin                            68105    3453692       4852820   118050.79
# Botswana                         27560    3704902       5259784    22339.92
# Burkina Faso                    328297    3778795       5431243   105051.33
# Cabo Verde                       44100    3396746       4787751    14576.94
# Cameroon                         46720    3916078       5663196   217630.28
# Central African Republic         49728    3607546       5069094    28739.02
# Chad                             52377    3606529       5108355    65940.17
# Comoros                           2025     124514        241681       32.00
# Congo                            64998    3792029       5445560    38699.26
# ...

# %%
food_data_df.mean()

#The mean of the dataset to 2 decimal places is 140.92
# Out:
# C:\Users\Ofonime Obot\AppData\Local\Temp\ipykernel_7756\2119799205.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   food_data_df.mean()
# Area Code        134.265576
# Item Code       2687.176706
# Element Code    3814.856456
# Y2014            134.196282
# Y2015            135.235966
# Y2016            136.555222
# Y2017            140.917765
# Y2018            143.758381
# dtype: float64

# %%
food_data_df.std()

#The standard deviation of the dataset to 2 decimal places is 1671.86
# Out:
# C:\Users\Ofonime Obot\AppData\Local\Temp\ipykernel_7756\1330606609.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   food_data_df.std()
# Area Code         72.605709
# Item Code        146.055739
# Element Code    2212.007033
# Y2014           1567.663696
# Y2015           1603.403984
# Y2016           1640.007194
# Y2017           1671.862359
# Y2018           1710.782658
# dtype: float64

# %%
food_data_df.groupby('Item').sum()

#The total sum of wine produced in 2015 is 4251.81. The total sum for 2018 is 4039.32
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
food_data_df.groupby('Area').count()

#This is used to find the number of countries in the dataset, total is 49 countries.
# Out:
#                              Area Code  Item Code  Item  Element Code  \
# Area
# Algeria                           1313       1313  1313          1313
# Angola                            1424       1424  1424          1424
# Benin                             1285       1285  1285          1285
# Botswana                          1378       1378  1378          1378
# Burkina Faso                      1409       1409  1409          1409
# Cabo Verde                        1260       1260  1260          1260
# Cameroon                          1460       1460  1460          1460
# Central African Republic          1344       1344  1344          1344
# Chad                              1343       1343  1343          1343
# Comoros                             45         45    45            45
# Congo                             1413       1413  1413          1413
# Côte d'Ivoire                     1467       1467  1467          1467
# ...

# %%
cr = food_data_df.corr().abs()
print(cr)

#From this the year Y2016 has the least correlation with Element code. 0.0234444
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000   0.005159      0.000209  0.006164  0.005472
# Item Code      0.005159   1.000000      0.024683  0.021722  0.020857
# Element Code   0.000209   0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
#Question 8

lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30, 'Brazil', 92]]
columns = ['Age', 'Nationality', 'Overall']

pd.DataFrame(lst, columns = ['Age', 'Nationality', 'Overall'], index = [1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
#Question 10, this is to show the rows and columns of the dataframe.

df = pd.DataFrame(lst, columns = ['Age', 'Nationality', 'Overall'], index = [1,2,3])

df.shape
# Out:
# (3, 3)

# %%
#Question 11

my_tuppy = (1,2,5,8)

my_tuppy[2] = 6

#This gives a type Error.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7756\1506035021.py in <module>
#       3 my_tuppy = (1,2,5,8)
#       4
# ----> 5 my_tuppy[2] = 6
#       6
#       7 #This gives a type Error.
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Question 13

food_data_df.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
#Question 12

food_data_df.groupby('Element').sum().iloc['Protein Quantity']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7756\2944872035.py in <module>
#       1 #Question 12
#       2
# ----> 3 food_data_df.groupby('Element').sum().iloc['Protein Quantity']
#
# ~\Documents\HamoyeHQ Internship\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~\Documents\HamoyeHQ Internship\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1518             key = item_from_zerodim(key)
#    1519             if not is_integer(key):
# -> 1520                 raise TypeError("Cannot index by location index with a non-integer key")
#    1521
# ...

# %%
food_data_df.groupby('Area')['Y2017'].sum()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
#Question 15

array = ([[94, 89, 63], [92, 93, 48], [92, 94, 56]])
print(array)

a = np.array(array)

a[:1, 1:]


#THis is to select the item in bold
# Out:
# [[94, 89, 63], [92, 93, 48], [92, 94, 56]]
# array([[89, 63]])

# %%
#Q16

S=[['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'

# %%
#Q17

y = [(2,4), (7,8), (1, 5, 9)]

y[1][-1]
# Out:
# 8

# %%
n = food_data_df.isnull().sum()
print(n)
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
o = food_data_df.notnull().sum()
print(o)
# Out:
# Area Code       60943
# Area            60943
# Item Code       60943
# Item            60943
# Element Code    60943
# Element         60943
# Unit            60943
# Y2014           59354
# Y2015           59395
# Y2016           59408
# Y2017           59437
# Y2018           59507
# dtype: int64

# %%
food_data_df.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
#I am unsure of Question 12...
